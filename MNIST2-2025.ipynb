# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist #to import our dataset
from tensorflow.keras.models import Sequential, Model # imports our type of network
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input, BatchNormalization # imports our layers we want to use

from tensorflow.python.keras.losses import categorical_crossentropy #loss function
from tensorflow.keras.optimizers import Adam, SGD #optimisers
from tensorflow.keras.utils import to_categorical #some function for data preparation

from tensorflow.keras.callbacks import ModelCheckpoint #checkpoints used to keep track of best model

from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('float32')

# %%
batch_size = 128
num_classes = 10
epochs = 20

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()


x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28)
# y_train shape: (60000,)
# 60000 train samples
# 10000 test samples

# %%
input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu')(x)
x = Dense(200, activation='relu')(x)
y = Dense(num_classes, activation='softmax')(x)

model= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# 2025-11-17 21:21:03.000696: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-11-17 21:21:03.000827: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-11-17 21:21:03.001035: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-11-17 21:21:03.001453: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-17 21:21:03.001964: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,210 (778.16 KB)
#  Trainable params: 199,210 (778.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history1=model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 2025-11-17 21:21:04.125489: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8800 - loss: 0.4233 - val_accuracy: 0.8902 - val_loss: 0.4074
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8437 - loss: 1.0070 - val_accuracy: 0.8005 - val_loss: 1.8105
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8110 - loss: 2.6784 - val_accuracy: 0.8031 - val_loss: 4.1457
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8064 - loss: 4.4114 - val_accuracy: 0.7515 - val_loss: 8.5616
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8069 - loss: 6.6509 - val_accuracy: 0.8597 - val_loss: 4.8640
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8014 - loss: 8.7267 - val_accuracy: 0.8232 - val_loss: 7.9509
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8068 - loss: 10.5831 - val_accuracy: 0.7844 - val_loss: 13.6528
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8074 - loss: 12.6862 - val_accuracy: 0.8525 - val_loss: 9.5177
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8014 - loss: 16.4426 - val_accuracy: 0.7647 - val_loss: 26.5125
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8031 - loss: 18.7542 - val_accuracy: 0.7925 - val_loss: 21.3573
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8015 - loss: 22.3531 - val_accuracy: 0.8292 - val_loss: 17.3664
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8025 - loss: 24.7438 - val_accuracy: 0.7824 - val_loss: 32.6315
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8051 - loss: 27.2407 - val_accuracy: 0.8081 - val_loss: 29.7483
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7983 - loss: 33.3767 - val_accuracy: 0.8221 - val_loss: 27.5541
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7955 - loss: 38.0817 - val_accuracy: 0.7958 - val_loss: 34.4299
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7962 - loss: 42.2123 - val_accuracy: 0.7912 - val_loss: 43.9385
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7933 - loss: 50.2759 - val_accuracy: 0.7935 - val_loss: 57.3009
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7987 - loss: 50.8917 - val_accuracy: 0.7461 - val_loss: 66.2506
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8000 - loss: 53.6665 - val_accuracy: 0.8092 - val_loss: 45.2242
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.7978 - loss: 60.5768 - val_accuracy: 0.7739 - val_loss: 62.7995

# %%
# Let's add some regularisation:

from tensorflow.keras.regularizers import l1, l2

#dropout_rate = 0.2

input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu',activity_regularizer=l1(0.1))(x)
x = Dense(200, activation='relu',activity_regularizer=l1(0.2))(x)
y = Dense(num_classes, activation='softmax')(x)

model= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,210 (778.16 KB)
#  Trainable params: 199,210 (778.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Dropout

dropout_rate = 0.2

input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu',activity_regularizer=l1(0.1))(x)
x = Dropout(rate=dropout_rate)(x)
x = Dense(200, activation='relu',activity_regularizer=l1(0.2))(x)
x = Dropout(rate=dropout_rate)(x)
y = Dense(num_classes, activation='softmax')(x)

model_dropout= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model_dropout.compile(loss='mse',optimizer=opt, metrics=['accuracy'])
model_dropout.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 199,210 (778.16 KB)
#  Trainable params: 199,210 (778.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history4=model_dropout.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.1419 - loss: 18120.5449 - val_accuracy: 0.4867 - val_loss: 20225.0098
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2028 - loss: 20675.4238 - val_accuracy: 0.5324 - val_loss: 21636.6934
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2498 - loss: 21758.3711 - val_accuracy: 0.5546 - val_loss: 22471.2129
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2742 - loss: 22411.0332 - val_accuracy: 0.5691 - val_loss: 23030.3789
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2843 - loss: 23010.9043 - val_accuracy: 0.5771 - val_loss: 23716.5801
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2846 - loss: 23600.0703 - val_accuracy: 0.5350 - val_loss: 24091.3457
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2840 - loss: 23945.1855 - val_accuracy: 0.4310 - val_loss: 24510.3848
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.2812 - loss: 24633.2539 - val_accuracy: 0.4457 - val_loss: 25255.8789
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.2811 - loss: 25152.2266 - val_accuracy: 0.5715 - val_loss: 25803.5664
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2843 - loss: 25668.3242 - val_accuracy: 0.4506 - val_loss: 26377.4004
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2806 - loss: 26252.6250 - val_accuracy: 0.3475 - val_loss: 27054.9336
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2780 - loss: 27103.7949 - val_accuracy: 0.4303 - val_loss: 27788.5352
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2774 - loss: 27557.8047 - val_accuracy: 0.3618 - val_loss: 28019.5195
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2754 - loss: 28044.5020 - val_accuracy: 0.5007 - val_loss: 28739.5684
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2742 - loss: 28442.5723 - val_accuracy: 0.4528 - val_loss: 29031.1465
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2779 - loss: 28801.0430 - val_accuracy: 0.3177 - val_loss: 29376.6953
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2672 - loss: 29259.8516 - val_accuracy: 0.4262 - val_loss: 30032.8535
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.2717 - loss: 29755.6934 - val_accuracy: 0.3235 - val_loss: 30564.2500
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.2704 - loss: 30362.9180 - val_accuracy: 0.3910 - val_loss: 30861.0137
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2706 - loss: 30429.2910 - val_accuracy: 0.4380 - val_loss: 31112.1641

# %%
tf.__version__
# Out:
# '2.16.2'

# %%
# Batch-Normalisation

dropout_rate = 0.2

input_network = Input(shape=(28,28))
x = Flatten()(input_network)
x = Dense(200, activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(200, activation='relu')(x)
x = Dropout(rate=dropout_rate)(x)
y = Dense(num_classes, activation='softmax')(x)

model_batch_normalisation= Model(input_network,outputs=y)
opt = Adam(learning_rate=0.001)
model_batch_normalisation.compile(loss='mse',optimizer=opt, metrics=['accuracy'])
model_batch_normalisation.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200)            │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 200,010 (781.29 KB)
#  Trainable params: 199,610 (779.73 KB)
#  Non-trainable params: 400 (1.56 KB)

# %%
history4=model_batch_normalisation.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8585 - loss: 0.0213 - val_accuracy: 0.9022 - val_loss: 0.0161
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8684 - loss: 0.0222 - val_accuracy: 0.9062 - val_loss: 0.0163
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.8661 - loss: 0.0241 - val_accuracy: 0.9043 - val_loss: 0.0174
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8633 - loss: 0.0252 - val_accuracy: 0.9010 - val_loss: 0.0186
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8680 - loss: 0.0249 - val_accuracy: 0.9041 - val_loss: 0.0181
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8632 - loss: 0.0261 - val_accuracy: 0.9034 - val_loss: 0.0184
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8643 - loss: 0.0261 - val_accuracy: 0.9016 - val_loss: 0.0189
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8682 - loss: 0.0255 - val_accuracy: 0.9055 - val_loss: 0.0183
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8652 - loss: 0.0262 - val_accuracy: 0.8906 - val_loss: 0.0213
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8642 - loss: 0.0265 - val_accuracy: 0.8958 - val_loss: 0.0202
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8611 - loss: 0.0271 - val_accuracy: 0.8947 - val_loss: 0.0207
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8623 - loss: 0.0270 - val_accuracy: 0.8989 - val_loss: 0.0198
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8601 - loss: 0.0275 - val_accuracy: 0.8921 - val_loss: 0.0213
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8635 - loss: 0.0269 - val_accuracy: 0.8897 - val_loss: 0.0217
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8603 - loss: 0.0275 - val_accuracy: 0.8675 - val_loss: 0.0261
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8561 - loss: 0.0284 - val_accuracy: 0.8977 - val_loss: 0.0202
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8587 - loss: 0.0279 - val_accuracy: 0.8961 - val_loss: 0.0205
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8607 - loss: 0.0275 - val_accuracy: 0.8898 - val_loss: 0.0218
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8602 - loss: 0.0277 - val_accuracy: 0.8904 - val_loss: 0.0217
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8593 - loss: 0.0278 - val_accuracy: 0.8841 - val_loss: 0.0230

# %%
# Saving a model

# Save the model
model_batch_normalisation.save('mnist_model_batch_normalisation.keras')


# Load the model
loaded_model = tf.keras.models.load_model('mnist_model_batch_normalisation.keras')
print("Model loaded from 'mnist_model_batch_normalisation.keras")

# Evaluate the loaded model
loss, accuracy = loaded_model.evaluate(x_test, y_test)
# Out:
# Model loaded from 'mnist_model_batch_normalisation.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8841 - loss: 0.0230

# %%
# keeping the best model on the test/validation data.

# Define a ModelCheckpoint callback
checkpoint = ModelCheckpoint('best_model.keras', 
                             monitor='val_accuracy',  # You can monitor 'val_loss' or any other metric
                             save_best_only=True, 
                             mode='max',  # Use 'max' if monitoring accuracy; 'min' if monitoring loss
                             verbose=1)

history4=model_batch_normalisation.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=[checkpoint],
          validation_data=(x_test, y_test))

best_model = tf.keras.models.load_model('best_model.keras')
# Out:
# Epoch 1/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8595 - loss: 0.0279
# Epoch 1: val_accuracy improved from None to 0.87270, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.8600 - loss: 0.0278 - val_accuracy: 0.8727 - val_loss: 0.0252
# Epoch 2/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8529 - loss: 0.0291
# Epoch 2: val_accuracy improved from 0.87270 to 0.88180, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8555 - loss: 0.0286 - val_accuracy: 0.8818 - val_loss: 0.0235
# Epoch 3/20
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8565 - loss: 0.0285
# Epoch 3: val_accuracy improved from 0.88180 to 0.89750, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8552 - loss: 0.0287 - val_accuracy: 0.8975 - val_loss: 0.0203
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8625 - loss: 0.0273
# Epoch 4: val_accuracy improved from 0.89750 to 0.90290, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8633 - loss: 0.0271 - val_accuracy: 0.9029 - val_loss: 0.0192
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8651 - loss: 0.0268
# Epoch 5: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8588 - loss: 0.0280 - val_accuracy: 0.8886 - val_loss: 0.0222
# Epoch 6/20
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8595 - loss: 0.0279
# Epoch 6: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8620 - loss: 0.0274 - val_accuracy: 0.8925 - val_loss: 0.0214
# Epoch 7/20
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8597 - loss: 0.0278
# Epoch 7: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8589 - loss: 0.0280 - val_accuracy: 0.8876 - val_loss: 0.0223
# Epoch 8/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8581 - loss: 0.0281
# Epoch 8: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8576 - loss: 0.0283 - val_accuracy: 0.8955 - val_loss: 0.0207
# Epoch 9/20
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8659 - loss: 0.0266
# Epoch 9: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8646 - loss: 0.0269 - val_accuracy: 0.8919 - val_loss: 0.0215
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8533 - loss: 0.0291
# Epoch 10: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 886s 2s/step - accuracy: 0.8537 - loss: 0.0291 - val_accuracy: 0.8903 - val_loss: 0.0218
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8543 - loss: 0.0290
# Epoch 11: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8596 - loss: 0.0279 - val_accuracy: 0.8810 - val_loss: 0.0237
# Epoch 12/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8582 - loss: 0.0282
# Epoch 12: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8582 - loss: 0.0282 - val_accuracy: 0.8953 - val_loss: 0.0208
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8556 - loss: 0.0287
# Epoch 13: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8604 - loss: 0.0277 - val_accuracy: 0.8912 - val_loss: 0.0216
# Epoch 14/20
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8515 - loss: 0.0295
# Epoch 14: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8523 - loss: 0.0294 - val_accuracy: 0.8840 - val_loss: 0.0231
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8548 - loss: 0.0289
# Epoch 15: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8571 - loss: 0.0284 - val_accuracy: 0.8946 - val_loss: 0.0210
# Epoch 16/20
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8553 - loss: 0.0288
# Epoch 16: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8487 - loss: 0.0301 - val_accuracy: 0.8790 - val_loss: 0.0241
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8535 - loss: 0.0292
# Epoch 17: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8569 - loss: 0.0285 - val_accuracy: 0.8803 - val_loss: 0.0238
# Epoch 18/20
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8569 - loss: 0.0285
# Epoch 18: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8583 - loss: 0.0282 - val_accuracy: 0.8887 - val_loss: 0.0221
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.8688 - loss: 0.0261
# Epoch 19: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 324s 693ms/step - accuracy: 0.8694 - loss: 0.0260 - val_accuracy: 0.8787 - val_loss: 0.0242
# Epoch 20/20
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8568 - loss: 0.0285
# Epoch 20: val_accuracy did not improve from 0.90290
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8567 - loss: 0.0285 - val_accuracy: 0.8833 - val_loss: 0.0232

# %%
import optuna

# Optuna objective function
def objective(trial):
    # Suggest hyperparameters
    num_layers = trial.suggest_int('num_layers', 1, 3)
    activation = trial.suggest_categorical('activation', ['relu', 'sigmoid'])
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.5)
    units = trial.suggest_int('units', 32, 128)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    
    # Build the model
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28)))
    
    for _ in range(num_layers):
        model.add(Dense(units=units, activation=activation))
        model.add(Dropout(rate=dropout_rate))
    
    model.add(Dense(10, activation='softmax'))
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    # Train the model
    history = model.fit(x_train, y_train, 
                        validation_split=0.2,
                        epochs=5,  # To keep it quick for demonstration; you can increase it
                        batch_size=128, 
                        verbose=0)
    
    # Evaluate the model
    score = model.evaluate(x_test, y_test, verbose=0)
    accuracy = score[1]
    return accuracy

# Create an Optuna study and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)  # Set the number of trials

# Print the best trial
print('Best trial:')
print(f' Value: {study.best_trial.value}')
print(' Params: ')
for key, value in study.best_trial.params.items():
    print(f'    {key}: {value}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import optuna
#       3 # Optuna objective function
#       4 def objective(trial):
#       5     # Suggest hyperparameters
#
# ModuleNotFoundError: No module named 'optuna'
